# %%
# !pip install dtale
# Out:
# ...
#   Created wheel for Flask-Compress: filename=Flask_Compress-1.5.0-py3-none-any.whl size=5277 sha256=354988382d65bf334d02dce203816bcb379dba2f844420392f3fa454dbc4b5eb
#   Stored in directory: c:\users\goutham-rog\appdata\local\pip\cache\wheels\39\3f\1a\07c215cf8b8f924cde78277257a31e254ef267ade7a99c909e
# ...
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62603 sha256=2d1af69c1cebd3b749252546e9213fd3e81888e6c61aea81a5459b3a283033de
#   Stored in directory: c:\users\goutham-rog\appdata\local\pip\cache\wheels\fe\33\33\172dbfe1efc739352828854a113df599a428b58f68ed0c4f75
# ...
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669707 sha256=64a7e551f0b6fc7fa35f91b69e704d9f33d4a797f06af4d4abca68321f76088c
#   Stored in directory: c:\users\goutham-rog\appdata\local\pip\cache\wheels\00\35\e5\57e90f10c529601c6627400513cb65dd5adb09752411f5a050
# ...

# %% [markdown]
# https://pypi.org/project/dtale/

# %%
import dtale
import pandas as pd

# %%
#loading data
df = pd.read_csv(r"C:\\Users\\Goutham-ROG\\Documents\\1-Codes\\Python - codes\\IML(Numpy)\\Assignments\\EDA + DV\\attrition.csv")

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel              Department EducationField  \
# 0   41          1      Travel_Rarely                   Sales  Life Sciences
# 1   49          0  Travel_Frequently  Research & Development  Life Sciences
# 2   37          1      Travel_Rarely  Research & Development          Other
# 3   33          0  Travel_Frequently  Research & Development  Life Sciences
# 4   27          0      Travel_Rarely  Research & Development        Medical
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobSatisfaction  \
# 0                        2  Female               3         2                4
# 1                        3    Male               2         2                2
# 2                        4    Male               2         1                3
# 3                        4  Female               3         1                3
# 4                        1    Male               3         1                2
#
# ...

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Goutahm-ROG:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
