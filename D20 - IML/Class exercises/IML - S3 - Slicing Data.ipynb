# %% [markdown]
# ## Machine Learning - Session 3 -Slicing Data

# %%
# %pwd
# Out:
# 'C:\\Users\\Goutham-ROG\\Documents\\1-Codes\\Python - codes\\IML(Numpy)\\Class exercises'

# %%
# Set the working directory
import os
os.chdir(r"C:\\Users\\Goutham-ROG\\Documents\\1-Codes\\Python - codes\\IML(Numpy)\\Class exercises")

#Read the cars.csv data
import pandas as pd
cars = pd.read_csv("cars.csv")

# %% [markdown]
# #### 1. Choosing multiple columns

# %%
cars.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %%
#Select the coumns MPG, Weight and Horsepower
cars[["MPG","Weight","Horsepower"]]
# Out:
#       MPG  Weight  Horsepower
# 0    18.0    3504         130
# 1    15.0    3693         165
# 2    18.0    3436         150
# 3    16.0    3433         150
# 4    17.0    3449         140
# ..    ...     ...         ...
# 401  27.0    2790          86
# 402  44.0    2130          52
# 403  32.0    2295          84
# 404  28.0    2625          79
# 405  31.0    2720          82
#
# [406 rows x 3 columns]

# %%
#Using iloc (iloc allows you to give the indices)
cars.iloc[1:3,[1,5,4]]  
        #first row info print(1,2 rows)
                #column info, selects 1,5,4 columns
#similar to np 2d array.
# Out:
#     MPG  Weight  Horsepower
# 1  15.0    3693         165
# 2  18.0    3436         150

# %%
#OR Using loc (loc allows you to give the names)
cars.loc[:,["MPG","Weight","Horsepower"]]
# Out:
#       MPG  Weight  Horsepower
# 0    18.0    3504         130
# 1    15.0    3693         165
# 2    18.0    3436         150
# 3    16.0    3433         150
# 4    17.0    3449         140
# ..    ...     ...         ...
# 401  27.0    2790          86
# 402  44.0    2130          52
# 403  32.0    2295          84
# 404  28.0    2625          79
# 405  31.0    2720          82
#
# [406 rows x 3 columns]

# %%
cars.loc[1:3,["MPG","Weight","Horsepower"]]
#this is the only place where last index(row) is included.
# Out:
#     MPG  Weight  Horsepower
# 1  15.0    3693         165
# 2  18.0    3436         150
# 3  16.0    3433         150

# %% [markdown]
# #### 3. Choosing rows

# %%
#A. Choosing a single row from a single variable
cars.MPG[0]
# Out:
# 18.0

# %%
#OR
cars["MPG"][0]
# Out:
# 18.0

# %%
#OR using iloc
cars.iloc[0,1]
# Out:
# 18.0

# %%
#OR using loc
cars.loc[0,"MPG"]
# Out:
# 18.0

# %%
#B. Slicing few rows from a single variable
cars.MPG[10:20]
# Out:
# 10     0.0
# 11     0.0
# 12     0.0
# 13     0.0
# 14     0.0
# 15    15.0
# 16    14.0
# 17     0.0
# 18    15.0
# 19    14.0
# Name: MPG, dtype: float64

# %%
#OR using loc
cars.iloc[10:20,1]
# Out:
# 10     0.0
# 11     0.0
# 12     0.0
# 13     0.0
# 14     0.0
# 15    15.0
# 16    14.0
# 17     0.0
# 18    15.0
# 19    14.0
# Name: MPG, dtype: float64

# %%
#C. Choosing some specific rows from  particular variable
cars.loc[[1,4,6],"MPG"]
# Out:
# 1    15.0
# 4    17.0
# 6    14.0
# Name: MPG, dtype: float64

# %%
#D. Choosing some observations from all the variables
cars.loc[[1,4,6],:]
# Out:
#                  Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 1  Buick Skylark 320  15.0          8         350.0         165    3693
# 4        Ford Torino  17.0          8         302.0         140    3449
# 6   Chevrolet Impala  14.0          8         454.0         220    4354
#
#    Acceleration  Model Origin
# 1          11.5     70     US
# 4          10.5     70     US
# 6           9.0     70     US

# %%
#OR simply
cars.loc[[1,4,6]]
# Out:
#                  Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 1  Buick Skylark 320  15.0          8         350.0         165    3693
# 4        Ford Torino  17.0          8         302.0         140    3449
# 6   Chevrolet Impala  14.0          8         454.0         220    4354
#
#    Acceleration  Model Origin
# 1          11.5     70     US
# 4          10.5     70     US
# 6           9.0     70     US

# %% [markdown]
# #### 4. Practice

# %%
#a) Extract the information of the first 5 rows and firt 5 columns of the dataa
cars.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %%
cars.tail()
# Out:
#                    Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 401    Ford Mustang GL  27.0          4         140.0          86    2790
# 402  Volkswagen Pickup  44.0          4          97.0          52    2130
# 403      Dodge Rampage  32.0          4         135.0          84    2295
# 404        Ford Ranger  28.0          4         120.0          79    2625
# 405         Chevy S-10  31.0          4         119.0          82    2720
#
#      Acceleration  Model  Origin
# 401          15.6     82      US
# 402          24.6     82  Europe
# 403          11.6     82      US
# 404          18.6     82      US
# 405          19.4     82      US

# %%
#b) Extract the information of 20th-29th rows
cars.iloc[20:30,:]
# Out:
#                              Car   MPG  Cylinders  Displacement  Horsepower  \
# 20        Toyota Corolla Mark ii  24.0          4         113.0          95
# 21               Plymouth Duster  22.0          6         198.0          95
# 22                    AMC Hornet  18.0          6         199.0          97
# 23                 Ford Maverick  21.0          6         200.0          85
# 24                  Datsun PL510  27.0          4          97.0          88
# 25  Volkswagen 1131 Deluxe Sedan  26.0          4          97.0          46
# 26                   Peugeot 504  25.0          4         110.0          87
# 27                   Audi 100 LS  24.0          4         107.0          90
# 28                      Saab 99e  25.0          4         104.0          95
# 29                      BMW 2002  26.0          4         121.0         113
#
#     Weight  Acceleration  Model  Origin
# 20    2372          15.0     70   Japan
# 21    2833          15.5     70      US
# 22    2774          15.5     70      US
# 23    2587          16.0     70      US
# 24    2130          14.5     70   Japan
# 25    1835          20.5     70  Europe
# 26    2672          17.5     70  Europe
# 27    2430          14.5     70  Europe
# 28    2375          17.5     70  Europe
# 29    2234          12.5     70  Europe

# %%
#c) Extract the information of only the columns MPG, Cylinders and Weight
cars.iloc[:,[1,2,5]]
# Out:
#       MPG  Cylinders  Weight
# 0    18.0          8    3504
# 1    15.0          8    3693
# 2    18.0          8    3436
# 3    16.0          8    3433
# 4    17.0          8    3449
# ..    ...        ...     ...
# 401  27.0          4    2790
# 402  44.0          4    2130
# 403  32.0          4    2295
# 404  28.0          4    2625
# 405  31.0          4    2720
#
# [406 rows x 3 columns]

# %%
#d) Extract a random sample of size 100 from the data (SRSWOR)
cars.sample(100,replace= False,axis = 0)
# Out:
#                                    Car   MPG  Cylinders  Displacement  \
# 315                    Pontiac Phoenix  33.5          4         151.0
# 283                         Saab 99gle  21.6          4         121.0
# 231            Mercury Cougar Brougham  15.0          8         302.0
# 295                    Dodge St. Regis  18.2          8         318.0
# 79                    AMC Matador (sw)  15.0          8         304.0
# ..                                 ...   ...        ...           ...
# 307  Oldsmobile Cutlass Salon Brougham  23.9          8         260.0
# 160                     Chevrolet Nova  18.0          6         250.0
# 131                   Oldsmobile Omega  11.0          8         350.0
# 287                  Pontiac Lemans V6  21.5          6         231.0
# 218                 Mercedes-Benz 280s  16.5          6         168.0
#
#      Horsepower  Weight  Acceleration  Model  Origin
# 315          90    2556          13.2     79      US
# 283         115    2795          15.7     78  Europe
# 231         130    4295          14.9     77      US
# 295         135    3830          15.2     79      US
# 79          150    3892          12.5     72      US
# ..          ...     ...           ...    ...     ...
# 307          90    3420          22.2     79      US
# 160         105    3459          16.0     75      US
# 131         180    3664          11.0     73      US
# 287         115    3245          15.4     79      US
# 218         120    3820          16.7     76  Europe
#
# [100 rows x 9 columns]

# %%
#using np
import numpy as np
import pandas as pd

id = np.random.choice(100, replace = False,size = 100)  #size gives us o/p shape
df = cars.iloc[id]
df
# Out:
#                        Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 12        Ford Torino (sw)   0.0          8         351.0         153    4034
# 73      AMC Ambassador SST  17.0          8         304.0         150    3672
# 6         Chevrolet Impala  14.0          8         454.0         220    4354
# 62    Volkswagen Model 111  27.0          4          97.0          60    1834
# 64  Toyota Corolla Hardtop  24.0          4         113.0          95    2278
# ..                     ...   ...        ...           ...         ...     ...
# 15     Dodge Challenger SE  15.0          8         383.0         170    3563
# 7        Plymouth Fury iii  14.0          8         440.0         215    4312
# 29                BMW 2002  26.0          4         121.0         113    2234
# 60     Toyota Corolla 1200  31.0          4          71.0          65    1773
# 59               Fiat 124B  30.0          4          88.0          76    2065
#
#     Acceleration  Model  Origin
# 12          11.0     70      US
# 73          11.5     72      US
# 6            9.0     70      US
# 62          19.0     71  Europe
# 64          15.5     72   Japan
# ..           ...    ...     ...
# 15          10.0     70      US
# 7            8.5     70      US
# 29          12.5     70  Europe
# 60          19.0     71   Japan
# 59          14.5     71  Europe
#
# [100 rows x 9 columns]

# %% [markdown]
# #### 5. Condtional Subsetting

# %%
#a) Extract all the information of the cars which has MPG more than 40
cars.loc[cars.MPG >40,:]
# Out:
#                                  Car   MPG  Cylinders  Displacement  \
# 251  Volkswagen Rabbit Custom Diesel  43.1          4          90.0
# 316                Volkswagen Rabbit  41.5          4          98.0
# 329                        Mazda GLC  46.6          4          86.0
# 331                       Datsun 210  40.8          4          85.0
# 332     Volkswagen Rabbit C (Diesel)  44.3          4          90.0
# 333       Volkswagen Dasher (diesel)  43.4          4          90.0
# 336              Honda Civic 1500 gl  44.6          4          91.0
# 337             Renault Lecar Deluxe  40.9          4          85.0
# 402                Volkswagen Pickup  44.0          4          97.0
#
#      Horsepower  Weight  Acceleration  Model  Origin
# 251          48    1985          21.5     78  Europe
# 316          76    2144          14.7     80  Europe
# 329          65    2110          17.9     80   Japan
# 331          65    2110          19.2     80   Japan
# 332          48    2085          21.7     80  Europe
# 333          48    2335          23.7     80  Europe
# 336          67    1850          13.8     80   Japan
# 337           0    1835          17.3     80  Europe
# 402          52    2130          24.6     82  Europe

# %%
#b) Extract the information of the car/s which has only 3 cylinders
cars.loc[cars.Cylinders == 3, :]
# Out:
#                  Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 78   Mazda RX2 Coupe  19.0          3          70.0          97    2330
# 118        Mazda RX3  18.0          3          70.0          90    2124
# 250       Mazda RX-4  21.5          3          80.0         110    2720
# 341    Mazda RX-7 GS  23.7          3          70.0         100    2420
#
#      Acceleration  Model Origin
# 78           13.5     72  Japan
# 118          13.5     73  Japan
# 250          13.5     77  Japan
# 341          12.5     80  Japan

# %%
#c) Extract the information of all the cars originated in Europe and has Acceleration more than 20
cars.loc[(cars.Origin == 'Europe')&(cars.Acceleration > 20),:]
# Out:
#                                  Car   MPG  Cylinders  Displacement  \
# 25      Volkswagen 1131 Deluxe Sedan  26.0          4          97.0
# 66                 Volkswagen Type 3  23.0          4          97.0
# 109          Volkswagen Super Beetle  26.0          4          97.0
# 216                      Peugeot 504  19.0          4         120.0
# 251  Volkswagen Rabbit Custom Diesel  43.1          4          90.0
# 304               Mercedes Benz 300d  25.4          5         183.0
# 306                      Peugeot 504  27.2          4         141.0
# 332     Volkswagen Rabbit C (Diesel)  44.3          4          90.0
# 333       Volkswagen Dasher (diesel)  43.4          4          90.0
# 335               Mercedes-Benz 240d  30.0          4         146.0
# 366        Peugeot 505s Turbo Diesel  28.1          4         141.0
# 402                Volkswagen Pickup  44.0          4          97.0
#
#      Horsepower  Weight  Acceleration  Model  Origin
# 25           46    1835          20.5     70  Europe
# 66           54    2254          23.5     72  Europe
# 109          46    1950          21.0     73  Europe
# 216          88    3270          21.9     76  Europe
# 251          48    1985          21.5     78  Europe
# 304          77    3530          20.1     79  Europe
# 306          71    3190          24.8     79  Europe
# 332          48    2085          21.7     80  Europe
# 333          48    2335          23.7     80  Europe
# 335          67    3250          21.8     80  Europe
# 366          80    3230          20.4     81  Europe
# 402          52    2130          24.6     82  Europe

# %%
#d) Name the cars which has MPG more than 40 and Acceleration less than 20 or the car has three cylinders
cars.loc[((cars.MPG > 40)&(cars.Acceleration < 20))|(cars.Cylinders == 3), :]
# Out:
#                       Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 78        Mazda RX2 Coupe  19.0          3          70.0          97    2330
# 118             Mazda RX3  18.0          3          70.0          90    2124
# 250            Mazda RX-4  21.5          3          80.0         110    2720
# 316     Volkswagen Rabbit  41.5          4          98.0          76    2144
# 329             Mazda GLC  46.6          4          86.0          65    2110
# 331            Datsun 210  40.8          4          85.0          65    2110
# 336   Honda Civic 1500 gl  44.6          4          91.0          67    1850
# 337  Renault Lecar Deluxe  40.9          4          85.0           0    1835
# 341         Mazda RX-7 GS  23.7          3          70.0         100    2420
#
#      Acceleration  Model  Origin
# 78           13.5     72   Japan
# 118          13.5     73   Japan
# 250          13.5     77   Japan
# 316          14.7     80  Europe
# 329          17.9     80   Japan
# 331          19.2     80   Japan
# 336          13.8     80   Japan
# 337          17.3     80  Europe
# 341          12.5     80   Japan
