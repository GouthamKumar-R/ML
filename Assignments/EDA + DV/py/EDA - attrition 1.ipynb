# %% [markdown]
# Libraries:

# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

# %% [markdown]
# Loading data:

# %%
# %pwd
# Out:
# 'C:\\Users\\Goutham-ROG\\Documents\\DS studies\\College\\1st sem\\Intro to ML (IML -3.0)\\EDA + DV\\py'

# %%
df = pd.read_csv(r"C:\\Users\\Goutham-ROG\\Documents\\DS studies\\College\\1st sem\\Intro to ML (IML -3.0)\\EDA + DV\\attrition.csv")

# %%
df .head()
# Out:
#    Age  Attrition     BusinessTravel              Department EducationField  \
# 0   41          1      Travel_Rarely                   Sales  Life Sciences
# 1   49          0  Travel_Frequently  Research & Development  Life Sciences
# 2   37          1      Travel_Rarely  Research & Development          Other
# 3   33          0  Travel_Frequently  Research & Development  Life Sciences
# 4   27          0      Travel_Rarely  Research & Development        Medical
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobSatisfaction  \
# 0                        2  Female               3         2                4
# 1                        3    Male               2         2                2
# 2                        4    Male               2         1                3
# 3                        4  Female               3         1                3
# 4                        1    Male               3         1                2
#
#   MaritalStatus  MonthlyIncome OverTime  TotalWorkingYears  WorkLifeBalance  \
# 0        Single           5993      Yes                  8                1
# 1       Married           5130       No                 10                3
# 2        Single           2090      Yes                  7                3
# 3       Married           2909      Yes                  8                3
# 4       Married           3468       No                  6                3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager  DistanceFromHome
# 0                     5                 1
# 1                     7                 8
# 2                     0                 2
# 3                     0                 3
# 4                     2                 2

# %%
df.describe(include='all')
# Out:
#                 Age    Attrition BusinessTravel              Department  \
# count   1470.000000  1470.000000           1470                    1470
# unique          NaN          NaN              3                       3
# top             NaN          NaN  Travel_Rarely  Research & Development
# freq            NaN          NaN           1043                     961
# mean      36.923810     0.161224            NaN                     NaN
# std        9.135373     0.367863            NaN                     NaN
# min       18.000000     0.000000            NaN                     NaN
# 25%       30.000000     0.000000            NaN                     NaN
# 50%       36.000000     0.000000            NaN                     NaN
# 75%       43.000000     0.000000            NaN                     NaN
# max       60.000000     1.000000            NaN                     NaN
#
#        EducationField  EnvironmentSatisfaction Gender  JobInvolvement  \
# count            1470              1470.000000   1470     1470.000000
# unique              6                      NaN      2             NaN
# top     Life Sciences                      NaN   Male             NaN
# freq              606                      NaN    882             NaN
# mean              NaN                 2.721769    NaN        2.729932
# std               NaN                 1.093082    NaN        0.711561
# min               NaN                 1.000000    NaN        1.000000
# 25%               NaN                 2.000000    NaN        2.000000
# 50%               NaN                 3.000000    NaN        3.000000
# 75%               NaN                 4.000000    NaN        3.000000
# max               NaN                 4.000000    NaN        4.000000
#
#            JobLevel  JobSatisfaction MaritalStatus  MonthlyIncome OverTime  \
# count   1470.000000      1470.000000          1470    1470.000000     1470
# unique          NaN              NaN             3            NaN        2
# top             NaN              NaN       Married            NaN       No
# freq            NaN              NaN           673            NaN     1054
# mean       2.063946         2.728571           NaN    6502.931293      NaN
# std        1.106940         1.102846           NaN    4707.956783      NaN
# min        1.000000         1.000000           NaN    1009.000000      NaN
# 25%        1.000000         2.000000           NaN    2911.000000      NaN
# 50%        2.000000         3.000000           NaN    4919.000000      NaN
# 75%        3.000000         4.000000           NaN    8379.000000      NaN
# max        5.000000         4.000000           NaN   19999.000000      NaN
#
#         TotalWorkingYears  WorkLifeBalance  YearsAtCompany  \
# count         1470.000000      1470.000000     1470.000000
# unique                NaN              NaN             NaN
# top                   NaN              NaN             NaN
# freq                  NaN              NaN             NaN
# mean            11.279592         2.761224        7.008163
# std              7.780782         0.706476        6.126525
# min              0.000000         1.000000        0.000000
# 25%              6.000000         2.000000        3.000000
# 50%             10.000000         3.000000        5.000000
# 75%             15.000000         3.000000        9.000000
# max             40.000000         4.000000       40.000000
#
#         YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# count          1470.000000              1470.000000           1470.000000
# unique                 NaN                      NaN                   NaN
# top                    NaN                      NaN                   NaN
# freq                   NaN                      NaN                   NaN
# mean              4.229252                 2.187755              4.123129
# std               3.623137                 3.222430              3.568136
# min               0.000000                 0.000000              0.000000
# 25%               2.000000                 0.000000              2.000000
# 50%               3.000000                 1.000000              3.000000
# 75%               7.000000                 3.000000              7.000000
# max              18.000000                15.000000             17.000000
#
#         DistanceFromHome
# count        1470.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean            9.192517
# std             8.106864
# min             1.000000
# 25%             2.000000
# 50%             7.000000
# 75%            14.000000
# max            29.000000

# %%
df.YearsAtCompany.unique()
# Out:
# array([ 6, 10,  0,  8,  2,  7,  1,  9,  5,  4, 25,  3, 12, 14, 22, 15, 27,
#        21, 17, 11, 13, 37, 16, 20, 40, 24, 33, 19, 36, 18, 29, 31, 32, 34,
#        26, 30, 23], dtype=int64)

# %%
df.shape
# Out:
# (1470, 20)
